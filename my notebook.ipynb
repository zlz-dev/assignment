# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
#  <strong>zhou lanzhao</strong></br>
#  system engineer

# %% [markdown]
# I am interested in data science because it is so interesting

# %% [markdown]
# <h3>excute 1+1</h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# > Dorothy followed her through many of the beautiful rooms in her castle.</br>
# <ol>
#   <li>First item</li>
#   <li>Second item</li>
#   <li>Third item</li>
#   <li>Fourth item</li>
# </ol>
# <ul>
#   <li>First item</li>
#   <li>Second item</li>
#   <li>Third item</li>
#   <li>Fourth item</li>
# </ul>
# At the command prompt, type <code>nano</code>.
